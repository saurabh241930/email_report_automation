# %%
import json
from datetime import datetime, timedelta
import random
from datetime import date
from bson.objectid import ObjectId
import calendar
from utils import get_points,gen_start_end_date,get_project_shifts
from flask_mail import Mail, Message

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://dbChirag:dbChirag123@swatiprodcluster0.bmxsv.mongodb.net/swatiinteriors")
client
# Out:
# MongoClient(host=['swatiprodcluster0-shard-00-00.bmxsv.mongodb.net:27017', 'swatiprodcluster0-shard-00-02.bmxsv.mongodb.net:27017', 'swatiprodcluster0-shard-00-01.bmxsv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-xhd62v-shard-0', ssl=True)

# %%
# change this
db = client['swatiinteriors']
LOGS = db['logs']
projects = db['projects']
users = db['users']
attendances = db['attendances']
indents = db['indents']
indent_items = db['indent_items']
salaries = db['salaries']
employee_roles = db['employee_roles']
imeis = db['imeis']

# %%
def get_yesterday_footfall(user_site_preferences):
    today_date = datetime.strptime(datetime.today().strftime('%Y-%m-%d'), '%Y-%m-%d') -timedelta(days=1)
    user_site_preferences = ['INDIABULLS BLU-PENT HOUSE', 'DLF LIMITED']
    total_footfall_query = [{'$match': {'date': today_date,'site_name':{'$in':user_site_preferences}}},
                                {"$group": {'_id': '$site_name',
                                            'total_worker_footfall': {'$sum': 1},
                                            'average_working_hour_onsite': {'$avg': '$duration'}
                                            }}]

    total_footfall_project_wise_data = attendances.aggregate(total_footfall_query)
    return list(total_footfall_project_wise_data)


def get_today_footfall(user_site_preferences):
    today_date = datetime.strptime(datetime.today().strftime('%Y-%m-%d'), '%Y-%m-%d')
    user_site_preferences = ['INDIABULLS BLU-PENT HOUSE', 'DLF LIMITED']
    total_footfall_query = [{'$match': {'date': today_date,'site_name':{'$in':user_site_preferences}}},
                                {"$group": {'_id': '$site_name',
                                            'total_worker_footfall': {'$sum': 1},
                                            'average_working_hour_onsite': {'$avg': '$duration'}
                                            }}]

    total_footfall_project_wise_data = attendances.aggregate(total_footfall_query)
    return list(total_footfall_project_wise_data)


def get_week_footfall(user_site_preferences):
    
    total_footfall_query = [{'$match': {'site_name':user_site_preferences[0]}},
                                {"$group": {'_id':{'$week':'$date'},
                                            'total_worker_footfall': {'$sum': 1},
                                            'average_working_hour_onsite': {'$avg': '$duration'},
                                            }},{'$sort':{'_id':1}}]

    total_footfall_project_wise_data = attendances.aggregate(total_footfall_query)
    return list(total_footfall_project_wise_data)

def get_users_with_null_attendance_week(user_site_preferences):
    
    total_footfall_query = [{'$match': {'attendance_points':None,'site_name':user_site_preferences[0]}},
                                {"$group": {'_id': '$worker_full_name',
                                            'count': {'$sum': 1}
                                            }}]

    total_footfall_project_wise_data = attendances.aggregate(total_footfall_query)
    return list(total_footfall_project_wise_data)
    





get_users_with_null_attendance(['DLF LIMITED','INDIABULLS BLU-PENT HOUSE'])
# Out:
# [{'_id': 'KISHAN GOPI RAM  ', 'count': 9},
#  {'_id': 'KANA RAM BIRJA LAL', 'count': 1},
#  {'_id': 'PRAVIN  GOPINATH GAIKWAD', 'count': 1},
#  {'_id': 'CHANDRA MOHAN RAMCHANDRA  JATAV', 'count': 3},
#  {'_id': 'SITA RAM OM PRAKASH', 'count': 1},
#  {'_id': 'JAHID ALI YUSUF  ', 'count': 2},
#  {'_id': 'NEMA RAM KISAN RAM', 'count': 2},
#  {'_id': 'KISHOR  KHUMAN SINGH', 'count': 1},
#  {'_id': 'BRIJESH KUMAR MUSAFIR RAM', 'count': 2},
#  {'_id': 'MOHAN RAM SURJA RAM ', 'count': 3},
#  {'_id': 'MANOJ  RAMLAL SUTHAR', 'count': 5},
#  {'_id': 'BAJRANG LAL NIMARAM PRAJAPAT', 'count': 1},
#  {'_id': 'VIRENDRA   BHIMAL THAKUR', 'count': 2},
#  {'_id': 'DINESH KUMAR RAMCHANDAR', 'count': 4},
#  {'_id': 'KHERAJ RAM DHANNA  RAM JAT', 'count': 3},
#  {'_id': 'DINESH KUMAR LAKSHMAN SAH SAH', 'count': 1},
#  {'_id': 'HIRI OM MAHENDRA NAMDEV NAMDEV', 'count': 1},
#  {'_id': 'RAM BABU  SUKHDEV SHARMA', 'count': 1},
#  {'_id': 'SANTOSH MANOJ  SAH', 'count': 3},
#  {'_id': 'BHANWAR LAL NEMI CHAND JAT', 'count': 2},
#  {'_id': 'SAJID JAKIR', 'count': 3},
#  {'_id': 'BHANWAR LAL RAMESHWAR LAL ', 'count': 1},
#  {'_id': 'SAHIRAM MOHAN RAM -', 'count': 3},
#  {'_id': 'MAHADEV POBI YADAV', 'count': 2},
#  {'_id': 'VIRENDRA REVANT RAM SUTHAR', 'count': 4},
#  {'_id': 'PAVAN    LAKHAN', 'count': 4},
#  {'_id': 'BANTI RAMESH', 'count': 3},
#  {'_id': 'SHRI KISHAN GORI SHANKAR', 'count': 4},
#  {'_id': 'AKASH  MANGILAL SIKWAR', 'count': 1},
#  {'_id': 'ASHOK KISHAN DAS SWAMI', 'count': 3},
#  {'_id': 'DHARMRAJ DHANNI', 'count': 5},
#  {'_id': 'SUGREEN SINGH PURAN JATAV', 'count': 1},
#  {'_id': 'VISHNU  SUMER  YADAV', 'count': 6},
#  {'_id': 'PRAKASH BHAGIRATH NAI NAI', 'count': 1},
#  {'_id': 'RATAN  BISHAN SINGH', 'count': 1},
#  {'_id': 'SUJEET KUMAR INDRADEEP  SINGH', 'count': 2},
#  {'_id': 'RUPA RAM  HARI RAM', 'count': 3},
#  {'_id': 'MAMARAJ MEGHARAM SUTHAR', 'count': 3},
#  {'_id': 'Bipinbhai Kantibhai Boricha', 'count': 4},
#  {'_id': 'AMARJIT MAHENDRA PASWAN', 'count': 2},
#  {'_id': 'JITENDRA SINGH ROOP SINGH', 'count': 2},
#  {'_id': 'ADURAM BALURAM ', 'count': 2},
#  {'_id': 'LOKESH  PRAHALAD RAM CHHIMPA', 'count': 1},
#  {'_id': 'VINOD  MATADEEN KUSHWAHA', 'count': 3},
#  {'_id': 'MOHAN RAM NEMARAM SUTHAR', 'count': 5},
#  {'_id': 'BHANWARI LAL DANARAM', 'count': 4},
#  {'_id': 'SAWARMAL BHAWARLAL  ', 'count': 2},
#  {'_id': 'RAMDAYAL PABUDAN SUTHAR', 'count': 1},
#  {'_id': 'SUKHDEV DULA RAM ', 'count': 1},
#  {'_id': 'JETHA RAM KUSHLA RAM -', 'count': 6},
#  {'_id': 'BINOD KUMAR BHAGWANA RAM', 'count': 1},
#  {'_id': 'MANISH KUMAR RAMBABU PASWAN', 'count': 1},
#  {'_id': 'RAHUL KUMAR BHOLARAM BATHAM', 'count': 1},
#  {'_id': 'SHIV LAL HARITRAM SUTHAR', 'count': 2},
#  {'_id': 'SUNDER RAM RAM SURESH SUTHAR', 'count': 6},
#  {'_id': 'RIYAJ ROSHAN ALI ALI', 'count': 3},
#  {'_id': 'ANIL  ASAV RAWAT', 'count': 7},
#  {'_id': 'AMARJEET RAMCHANDRA  YADAV', 'count': 5},
#  {'_id': 'GIRDHARLAL HARI RAM ', 'count': 6},
#  {'_id': 'CHHEDILAL RAMCHANDAR ', 'count': 2},
#  {'_id': 'JAGMAL SINGH SAWAI SINGH RATHORE', 'count': 5},
#  {'_id': 'SIKANDAR MOHAMMED ISHAQ  ', 'count': 2},
#  {'_id': 'GYANSINGH PRAHLAD  KUSHWAHA', 'count': 2},
#  {'_id': 'CHANDAGI HUVAEE', 'count': 1},
#  {'_id': 'RAMACHANDRA  SHAMBHU  DAN', 'count': 1},
#  {'_id': 'BANTI HARIGYAN KUSHWAH', 'count': 3},
#  {'_id': 'CHEL SINGH BADAN LAL SINGH', 'count': 2},
#  {'_id': 'PAVAN MANJHI RAKESH', 'count': 1},
#  {'_id': 'KAILASH KUMAR DULI CHAND SUTHAR', 'count': 1},
#  {'_id': 'RAMJI HARIVILAS GOUR', 'count': 2},
#  {'_id': 'OM PRAKASH PABUDAN SUTHAR', 'count': 1},
#  {'_id': 'SHYAMAL KISHOR YUGAL SAH SAH', 'count': 2},
#  {'_id': 'RAJENDRA KUMAR ANGAD', 'count': 6},
#  {'_id': 'LILADHAR TILOK RAM ', 'count': 8},
#  {'_id': 'PRAKASH KUMAR VASHISHTH SINGH', 'count': 2},
#  {'_id': 'GYANDAS CHHOTU ', 'count': 9},
#  {'_id': 'DINESH SAGAR MAL', 'count': 2},
#  {'_id': 'MUNNI RAM PURKHARAM', 'count': 2},
#  {'_id': 'UPENDRA GIRISH SHARMA', 'count': 1},
#  {'_id': 'JAGDISH KUMAR MOHAN RAM', 'count': 1},
#  {'_id': 'MALCHAND PAPPU BHARGAV BHARGAV', 'count': 5},
#  {'_id': 'SONU  AMAR SINGH JATAV', 'count': 2},
#  {'_id': 'MUKESH  CHATAR  SWAMI', 'count': 1},
#  {'_id': 'BABU LAL KANARAM SUTHAR', 'count': 5},
#  {'_id': 'DINESH KUMAR RAMAKANT NISHAD NISHAD', 'count': 7},
#  {'_id': 'BHAJAN  PUNAM DAS DAS', 'count': 7},
#  {'_id': 'BHANWARI SITARAM SUTHAR', 'count': 6},
#  {'_id': 'ANUP KUMAR RAMJANAM NISHAD', 'count': 3},
#  {'_id': 'HARI RAM SHANKAR RAM', 'count': 4},
#  {'_id': 'JASRATH MAVSHIYA', 'count': 4},
#  {'_id': 'RAJWANT RADHESHYAM YADAV', 'count': 7},
#  {'_id': 'NAKUL RANA JAGDISH RANA RANA', 'count': 4},
#  {'_id': 'KALU ASU RAM RAM', 'count': 1},
#  {'_id': 'DILIP PRHALAD SINGH', 'count': 1},
#  {'_id': 'RAJU RAM RAMESHWAR LAL', 'count': 2},
#  {'_id': 'OM SINGH PUSAN SINGH', 'count': 2},
#  {'_id': 'DEVENDRA MANGILAL SHARMA', 'count': 8},
#  {'_id': 'SUNDAR BHIKHARAM SUTHAR', 'count': 6},
#  {'_id': 'BRIJMOHAN RAMJI KUSHWAH KUSHWAH', 'count': 7},
#  {'_id': 'NARAYAN RAM JIVAN RAM', 'count': 1},
#  {'_id': 'ARVINDRA  MANGI SHARMA SHARMA', 'count': 1},
#  {'_id': 'GURUVENDRA  HARI BHAJAN KUSHWAH', 'count': 2},
#  {'_id': 'LALU PRASAD SURESH', 'count': 4},
#  {'_id': 'MAGHARAM NARAYANRAM', 'count': 1},
#  {'_id': 'CHEDI RAMCHANDAR ', 'count': 2},
#  {'_id': 'RAM GYAN RAMSURAT  VISHWAKARMA', 'count': 1},
#  {'_id': 'PANNARAM NARAYAN RAM', 'count': 4},
#  {'_id': 'OM PRAKASH  NANU RAM NAI', 'count': 1},
#  {'_id': 'MANU KUMAR CHALAHI PRASAD KUSHAWAHA', 'count': 2},
#  {'_id': 'SURESH KUMAR MUNNI RAM', 'count': 2},
#  {'_id': 'AWDHESH ADHARE ', 'count': 4},
#  {'_id': 'ASHOK RAJARAM -', 'count': 6},
#  {'_id': 'SANT LAL PRABHU RAM', 'count': 6},
#  {'_id': 'RAMAVATAR  SHYAM SUNDAR TIWARI', 'count': 2},
#  {'_id': 'SHIV LAL BHAVAR SINGH SINGH', 'count': 1},
#  {'_id': 'BHOMARAM BHIYA RAM ', 'count': 2},
#  {'_id': 'BHAGIRATH TARU RAM -', 'count': 2},
#  {'_id': 'KISHAN LAL KHETA RAM DHAKA', 'count': 2},
#  {'_id': 'DHIRAJ ASHOK KUMAR SUTHAR', 'count': 1},
#  {'_id': 'GAGAN RAM JAGMALA RAM RAM', 'count': 3},
#  {'_id': 'BHAGIRATH  SUTHAR', 'count': 1},
#  {'_id': 'ARJUN LAL LABHU RAM', 'count': 2},
#  {'_id': 'MUKHTIYAR  JAFAR  ALI', 'count': 6},
#  {'_id': 'SHARWAN KUMAR NARAYAN RAM', 'count': 2},
#  {'_id': 'RAKESH GORARDHAN RAM', 'count': 1},
#  {'_id': 'LIKHMARAM JALU RAM ', 'count': 1},
#  {'_id': 'KULDEEP  RAM DAYAL SHARMA', 'count': 5},
#  {'_id': 'SHRAWAN KUMAR HARI RAM', 'count': 4},
#  {'_id': 'AAKIB JAVED TASLIM KHAN', 'count': 6},
#  {'_id': 'JAI KISHAN JAISDAS SWAMI', 'count': 2},
#  {'_id': 'JAHID ALI YUSUF', 'count': 1},
#  {'_id': 'HARIPAL  CHAITU VISHWAKARMA', 'count': 2},
#  {'_id': 'DINESH KEDAR', 'count': 4},
#  {'_id': 'HIMMAT BHANABHAI CHAUHAN', 'count': 4},
#  {'_id': 'RAGHVENDRA BHAROSHI JATAV', 'count': 6},
#  {'_id': 'BALU RAM MANI RAM  ', 'count': 2},
#  {'_id': 'MADAN LAL BAJRANG LAL', 'count': 1},
#  {'_id': 'NEMA RAM PHUSA RAM', 'count': 3},
#  {'_id': 'DEVENDRA KUMAR HARI CHARAN LAL GUPTA', 'count': 2},
#  {'_id': 'DEVI SINGH RAM SINGH SINGH', 'count': 1},
#  {'_id': 'OMADAS CHENA  DAS', 'count': 1},
#  {'_id': 'DEENDYAL  LACHCHA RATHOR', 'count': 6},
#  {'_id': 'SALMAN HAIDAR ALI', 'count': 4},
#  {'_id': 'PANKAJ KUMAR JINDAL SHARMA SHARMA', 'count': 3},
#  {'_id': 'JASARAM RAMU RAM ', 'count': 1},
#  {'_id': 'DHARASINGH RAMCHARAN JATAV', 'count': 6},
#  {'_id': 'RAMRATN SURAJ  DAS', 'count': 1},
#  {'_id': 'PREMCHAND MURLIDHAR SUTHAR', 'count': 4},
#  {'_id': 'OMPRAKASH ARJUN RAM MANDA', 'count': 4},
#  {'_id': 'RITESH KUMAR SHAMBHU  NISHAD', 'count': 1},
#  {'_id': 'ATUL KUMAR MAHENDRA  NAMDEV', 'count': 6},
#  {'_id': 'SHAHID KHAN TASLEEM KHAN', 'count': 2},
#  {'_id': 'Anil kumar Achhelal Jaiswar', 'count': 2},
#  {'_id': 'ISHVAR RAM HIRALAL SUTHAR', 'count': 2},
#  {'_id': 'VEDPRAKASH SOBARAN SAVITA', 'count': 2},
#  {'_id': 'NENURAM  KHUMARAM', 'count': 1},
#  {'_id': 'RAHUL SHEE LAL NAMDEV', 'count': 4},
#  {'_id': 'RAJURAM CHAINA RAM', 'count': 3},
#  {'_id': 'SUMER ROOP SINGH', 'count': 1},
#  {'_id': 'ANIL KUMAR SWAMI PRASAD CHOUDHARY', 'count': 1},
#  {'_id': 'BALMUKUND AJAMER KAPOLIYA', 'count': 3},
#  {'_id': 'RAJENDERA NANU SINGH', 'count': 2},
#  {'_id': 'CHHOTU  AMAR LAL KUSHWAH', 'count': 5},
#  {'_id': 'DURGESH MATADEEN ', 'count': 2},
#  {'_id': 'MANISH BHANWAR LAL SUTHAR', 'count': 7},
#  {'_id': 'LOKENDRA  SHARMA ', 'count': 7},
#  {'_id': 'BAL CHAND PREMSUKH', 'count': 1},
#  {'_id': 'SOHAN AIDAN RAM', 'count': 5},
#  {'_id': 'NAGENDRA SUMER YADAV', 'count': 5},
#  {'_id': 'SHANKAR RAM NARAYAN RAM BISSU', 'count': 1},
#  {'_id': 'NITESH KUMAR RAMSAMUJH -', 'count': 1},
#  {'_id': 'BAIJNATH HAREESHCHANDRA PANDEY', 'count': 2},
#  {'_id': 'BHAROSHI LAL SUKHA', 'count': 2},
#  {'_id': 'VIRENDRA RAMKARAN -', 'count': 5},
#  {'_id': 'DEVENDRA  DHARA SINGH JATAV', 'count': 1},
#  {'_id': 'VIKERAM ASHU SINGH RAJPUT', 'count': 2},
#  {'_id': 'JAY KRISHAN  RAJENDRA  SAH', 'count': 3},
#  {'_id': 'SONARAM MUNI RAM GAYNA', 'count': 2},
#  {'_id': 'RAMNRESH  GANESH JATAV', 'count': 2},
#  {'_id': 'MAHAVIR SHERA RAM ECHARA', 'count': 1},
#  {'_id': 'SHRWAN SINGH PADAM SINGH SINGH', 'count': 2},
#  {'_id': 'KALU RAM MOHAN RAM', 'count': 3},
#  {'_id': 'BALIRAM NANDLAL ', 'count': 5},
#  {'_id': 'SUNIL  CHEDI RAJBHAR', 'count': 3},
#  {'_id': 'KISHAN LAL DUDARAM', 'count': 2},
#  {'_id': 'AKRAM RAMJAN MOHAMMAD', 'count': 1},
#  {'_id': 'BHUPENDRA CHUTTAN JATAV JATAV', 'count': 2},
#  {'_id': 'RAJESH MUSAFIR -', 'count': 1},
#  {'_id': 'MANOJ PATIRAM JATAV', 'count': 1},
#  {'_id': 'RAJU  CHANDR  SINGH', 'count': 3},
#  {'_id': 'SONOO PATROO ', 'count': 2},
#  {'_id': 'BIRBAL RAM SURJA RAM -', 'count': 5},
#  {'_id': 'BHANI RAM ASHARAM RAM', 'count': 1},
#  {'_id': 'MOHAN RAMRAKH RAM', 'count': 1},
#  {'_id': 'SAHIRAM MOHAN RAM', 'count': 2},
#  {'_id': 'GOPI CHAMPARAM RAM', 'count': 1},
#  {'_id': 'ROHIT SAH KUSHESHWAR SAH', 'count': 3},
#  {'_id': 'SANTOSH VIRENDRA TIWARI', 'count': 2},
#  {'_id': 'MANGILAL RAMADHAN -', 'count': 1},
#  {'_id': 'DEVI SINGH SURESH CHAND JATAV JATAV', 'count': 2},
#  {'_id': 'KRISHAN KUMAR MAGHARAM JANGIR', 'count': 7},
#  {'_id': 'AAKASH KUMAR SODHAN NISHAD', 'count': 1},
#  {'_id': 'VIKRAM LAXMAN SINGH SINGH', 'count': 2},
#  {'_id': 'LUKMAN GULAM MAINUDIN MOHAMMAD', 'count': 3},
#  {'_id': 'PANKAJ SHROUTI 0', 'count': 9},
#  {'_id': 'PINTU KUMAR VIDYA SHANKAR KUSHWAHA', 'count': 4},
#  {'_id': 'MO.IMRAN MO.HUSAIN ', 'count': 2},
#  {'_id': 'DEDAR ALI MANJUR ALI ALI', 'count': 1},
#  {'_id': 'PAWAN  MISHRI SAH', 'count': 2},
#  {'_id': 'SHAHRUKH SABIR ALI ', 'count': 3},
#  {'_id': 'MUKESH LAXMINARAYAN PAREEK', 'count': 1},
#  {'_id': 'SHARVAN RAM DULA RAM godar', 'count': 10},
#  {'_id': 'BHAGIRATH TARACHAND MISTRY', 'count': 7},
#  {'_id': 'MANISH RAMNARESH YADAV', 'count': 11},
#  {'_id': 'TAYAB ALI NAJAB ALI ALI', 'count': 6},
#  {'_id': 'JITENDRA  KUMAR ', 'count': 4},
#  {'_id': 'RAHUL VIJAY  SINGH', 'count': 4},
#  {'_id': 'RAM PRAKASH CHANDRIKA SINGH', 'count': 4},
#  {'_id': 'SOVARAN PATIRAM', 'count': 5},
#  {'_id': 'MUNNA KUMAR SINGH SHURMA SINGH SINGH', 'count': 5},
#  {'_id': 'SUNIL OMPRAKASH', 'count': 1},
#  {'_id': 'PARAMESHWAR LAL KUMBHA RAM  ', 'count': 2},
#  {'_id': 'SADDAM ABDUL GAFFAR', 'count': 5},
#  {'_id': 'GADIPAL ROSHAN', 'count': 1},
#  {'_id': 'DASHRAT SHYAMLAL MISTRY', 'count': 5},
#  {'_id': 'VIKRAM CHHOTURAM SUTHAR', 'count': 8},
#  {'_id': 'BAHADUR LALPATI JATAV', 'count': 1},
#  {'_id': 'MAHENDRA KUMAR BHAGAWANA RAM -', 'count': 5},
#  {'_id': 'GOPAL  SARVAN KUSHWAHA', 'count': 6},
#  {'_id': 'RAKESH LALA -', 'count': 1},
#  {'_id': 'PRAMOD RAJKUMAR ', 'count': 7},
#  {'_id': 'GOPI CHAND  MEGHA RAM SUTHAR', 'count': 2},
#  {'_id': 'OM PRAKASH MOOLA RAM GODARA', 'count': 3},
#  {'_id': 'SANJAY TEEKARAM BATHAM', 'count': 1},
#  {'_id': 'MANGILAL JAGDISH -', 'count': 4},
#  {'_id': 'PATIRAM HALUKA RAWAT', 'count': 1},
#  {'_id': 'Rakesh Kumar Ramratan Jatav', 'count': 1},
#  {'_id': 'OM PRAKASH NEMA RAM -', 'count': 7},
#  {'_id': 'MUNNI RAM KHIRAJ RAM GODARA', 'count': 2},
#  {'_id': 'TARACHAND OM PRAKASH PRAJAPAT', 'count': 1},
#  {'_id': 'SUBHASH HADMANA RAM SUTHAR', 'count': 1},
#  {'_id': 'SHAKIL MOHAMMAD SHARIF MOHAMMAD MOHAMMAD', 'count': 1},
#  {'_id': 'BIPIN KUMAR ARVIND BHAI PARMAR', 'count': 4},
#  {'_id': 'AJAY MAHENDRA  SINGH', 'count': 6},
#  {'_id': 'RANJAN KUMAR ANANT LAL DAS', 'count': 3},
#  {'_id': 'MANOJ MEENA MATADEEN MEENA', 'count': 3},
#  {'_id': 'JAYSINGH RAMAKANT YADAV', 'count': 7},
#  {'_id': 'RAMESH KUMAR ANNA RAM SUTHAR', 'count': 4},
#  {'_id': 'ASHARAM BANSI RAWAT RAWAT', 'count': 8},
#  {'_id': 'GOVIND  RATAN LAL SUTHAR', 'count': 7},
#  {'_id': 'DHARMENDRA AMAR SINGH SINGH', 'count': 5},
#  {'_id': 'BAJRANG LAL RAM PRATAP ', 'count': 2},
#  {'_id': 'NEERAJ RAMJI GOUR', 'count': 8},
#  {'_id': 'SALMAN 0 0', 'count': 12},
#  {'_id': 'Ibrahim Ali Salim  Ali', 'count': 1},
#  {'_id': 'KHET  RAMCHANDRA  PAL', 'count': 2},
#  {'_id': 'MUNNA KUMAR MANOJ  SAH', 'count': 3},
#  {'_id': 'KURBAN  MANJUR ALI', 'count': 1},
#  {'_id': 'SURAJ  BHOORA LAL SINGH', 'count': 4},
#  {'_id': 'SURESH SWAMI INDARAJ SWAMI', 'count': 2},
#  {'_id': 'SOHIL BHOLA KHAN KHAN', 'count': 8},
#  {'_id': 'DHEERENDRA  SHRINIWAS MUDGAL', 'count': 4},
#  {'_id': 'CHAIN SINGH NARAYAN SINGH SINGH', 'count': 2},
#  {'_id': 'SITARAM JAGO RANA', 'count': 3},
#  {'_id': 'MAHAVIR  MANGILAL SHARMA', 'count': 9},
#  {'_id': 'MD KASHIF ZAMA', 'count': 4},
#  {'_id': 'NADIM RAJAK MOHAMMAD', 'count': 2},
#  {'_id': 'BHAGIRATH HARI RAM DAS', 'count': 1},
#  {'_id': 'RAKESH KUMAR LAXMAN RAM', 'count': 1},
#  {'_id': 'AMARNATH SHANKAR ', 'count': 7},
#  {'_id': 'RAKESH KUMAR KHETA RAM', 'count': 4},
#  {'_id': 'HUKMI CHAND KANA RAM', 'count': 4},
#  {'_id': 'RABINDRA KUMAR MAHESH PRASAD SAH', 'count': 1},
#  {'_id': 'MANOJ KUMAR LAJJRAM', 'count': 2},
#  {'_id': 'UMESH KUMAR RAM BABU SHARMA', 'count': 1},
#  {'_id': 'RAMAVATAR JIGANLAL', 'count': 1},
#  {'_id': 'BHAGIRATHQ JAGDISH RAM ', 'count': 3},
#  {'_id': 'KHEM  KALYAN SINGH', 'count': 1},
#  {'_id': 'MUKESH  GIRDHARI LAL KHATI', 'count': 6},
#  {'_id': 'MANAK RAM  CHENA RAM  RAM', 'count': 1},
#  {'_id': 'DINESH KASHI PASWAN', 'count': 2},
#  {'_id': 'NARAYAN KUMAR SOHANLAL', 'count': 1},
#  {'_id': 'NARAYAN RAM JASARAM RAM', 'count': 2},
#  {'_id': 'RAUSHAN KUMAR RAJDEV SINGH', 'count': 2},
#  {'_id': 'SUNDAR LAL BHANWARLAL SUTHAR SUTHAR', 'count': 2},
#  {'_id': 'KARNA RAM', 'count': 1},
#  {'_id': 'RAKESH SITARAM SUTHAR', 'count': 4},
#  {'_id': 'HANUMAN DAS SAWMI', 'count': 1},
#  {'_id': 'SURALI RAMAVRIKSH -', 'count': 2},
#  {'_id': 'SONU  CHANTE KUSHWAH', 'count': 1},
#  {'_id': 'SHAILU KUMAR SURESH JATAV JATAV', 'count': 4},
#  {'_id': 'GOPAL RAM CHOKA RAM ', 'count': 5},
#  {'_id': 'SHRAWAN KUMAR PANNA RAM SUTHAR', 'count': 4},
#  {'_id': 'KRISHNA KUSHRAVI ', 'count': 3},
#  {'_id': 'ANSHUL BAIBEER KUSHAWAH', 'count': 1},
#  {'_id': 'SURENDRA SIVSAGAR PRASAD', 'count': 8},
#  {'_id': 'BHUP SINGH JANVED SINGH', 'count': 4},
#  {'_id': 'UMESH  RAMAKANT -', 'count': 4},
#  {'_id': 'MULA RAM GENA RAM -', 'count': 1},
#  {'_id': 'DIGVIJAY RAMDAS SINGH', 'count': 4},
#  {'_id': 'DEEPAK RADHESHYAM DARJI', 'count': 5},
#  {'_id': 'NARSINGH RAMAKANT YADAV', 'count': 6},
#  {'_id': 'RAKESH BHAGWAN SINGH', 'count': 2},
#  {'_id': 'MUKESH SHREE RAM PRATAP SINGH', 'count': 3},
#  {'_id': 'HARIOM HIRALAL', 'count': 1},
#  {'_id': 'SURENDRA RAMNARESH -', 'count': 1},
#  {'_id': 'MITHILESH KUMAR RAJENDRA SAH SAH', 'count': 3},
#  {'_id': 'PRAKASH KASHI RAM KUSHWAH', 'count': 3},
#  {'_id': 'SURAJ  MANGI LAL SIKARWAR', 'count': 2},
#  {'_id': 'RAM NIWAS CHUNNI LAL SUTHAR', 'count': 6},
#  {'_id': 'BECHAN  BANARSI  YADAV', 'count': 4},
#  {'_id': 'MAHENDR SHRI KALYAN NAMDEV', 'count': 3},
#  {'_id': 'ASHOK KUMAR GORI SUTHAR', 'count': 3},
#  {'_id': 'SUGHAR SHIV DAYAL JATAV JATAV', 'count': 5},
#  {'_id': 'RAJESH KUMAR VARUN', 'count': 1},
#  {'_id': 'LAKHAN  MISHRI SAH', 'count': 3},
#  {'_id': 'GULTEN SAH MAHANTHI   SAH', 'count': 3},
#  {'_id': 'SAMDAR LAL JAGDISH PRASAD SUTHAR', 'count': 1},
#  {'_id': 'VIRENDRA SINGH KHET SINGH', 'count': 1},
#  {'_id': 'SHYAM  SUNDAR SUTHAR', 'count': 15},
#  {'_id': 'VIJAY LALARAM RAJAK', 'count': 3},
#  {'_id': 'MANOHAR  SUKAI CHAUHAN', 'count': 6},
#  {'_id': 'DEVENDRA  BRAJRAJ  RATHORE', 'count': 1},
#  {'_id': 'SANDEEP RAJENDRA SENGAR', 'count': 5},
#  {'_id': 'NARESH  LALCHAND SHARMA SHARMA', 'count': 1},
#  {'_id': 'MUNNI RAM BHAGIRATH RAM -', 'count': 1},
#  {'_id': 'ANIL PARSURAM KUSHWAH', 'count': 3},
#  {'_id': 'SUNNEL VISHVANATH GUPTA', 'count': 5},
#  {'_id': 'PARAMESHWAR LAL KUMBHA RAM', 'count': 2},
#  {'_id': 'AJAJ MOHMMAD AKRAM RANGREJ', 'count': 1},
#  {'_id': 'SALEEM MUNSHI KHAN', 'count': 2},
#  {'_id': 'NORANG RAM GHASI RAM KHICHAR', 'count': 1},
#  {'_id': 'GHANSHYAM GYANARAM GODARA', 'count': 2},
#  {'_id': 'MUNIRAM RAGHUVIR  RAWAT', 'count': 4},
#  {'_id': 'SANJAY DHANIRAM KUSHWAH', 'count': 1},
#  {'_id': 'JAYESH MULAJIBHAI DAFDA', 'count': 8},
#  {'_id': 'PUNAM DAS MAMRAJ  SWAMI', 'count': 3},
#  {'_id': 'SHRAVAN KUMAR HADMAN KUMAR ', 'count': 2},
#  {'_id': 'ATUL  ARVIND  SHARMA', 'count': 3},
#  {'_id': 'LAXMAN RAM 0', 'count': 4},
#  {'_id': 'DURGESH KESAV DARJI', 'count': 5},
#  {'_id': 'PRABHU RAM HARU RAM SUTHAR', 'count': 1},
#  {'_id': 'FOOLSINGH MATTE RAWAT RAWAT', 'count': 7},
#  {'_id': 'RAMBABU NAGENDRA THAKUR', 'count': 3},
#  {'_id': 'ASHOK  SHARDA CHAUDHARI CHAUDHARI', 'count': 7},
#  {'_id': 'SANJAY  RAMNARAYAN PADWA', 'count': 1},
#  {'_id': 'KRISHNA RAJDEV', 'count': 1},
#  {'_id': 'NARESH RAM CHARAN SINGH', 'count': 6},
#  {'_id': 'SANJAY HARIPAL SHARMA', 'count': 2},
#  {'_id': 'RATANLAL  MAMRAJ SUTHAR', 'count': 1},
#  {'_id': 'GIRDHARI SINGH NARAYAN SINGH SINGH', 'count': 8},
#  {'_id': 'SALMAN BHANU KHAN', 'count': 3},
#  {'_id': 'Prakashbhai samatbhai boricha', 'count': 8},
#  {'_id': 'AFZAL HANIF MOHAMMAD', 'count': 1},
#  {'_id': 'ANKIT  KUMAR  SUTHAR', 'count': 6},
#  {'_id': 'ANIL  RAMNIVAS JATAV', 'count': 3},
#  {'_id': 'SHAILESH  SHRIKISHUN', 'count': 8},
#  {'_id': 'MUMTAJ MOHAMMAD KHURASHID RANGRAGE', 'count': 2},
#  {'_id': 'MAHESH  SARUP  KUSHWAH', 'count': 3},
#  {'_id': 'MOHAMMAD MUASLIM MOHAMMAD AYUB GARI', 'count': 2},
#  {'_id': 'DEVENDRA  GOPI', 'count': 2},
#  {'_id': 'DEEPAK KUMAR SHARMA  SINGH', 'count': 2},
#  {'_id': 'SOMAN SHIBU SHAH', 'count': 3},
#  {'_id': 'MUKESH BALI SUTHAR SHARMA', 'count': 1},
#  {'_id': 'VICKY  KAILASHI SHARMA SHARMA', 'count': 3},
#  {'_id': 'JITARAM BUDHARAM -', 'count': 10},
#  {'_id': 'LALCHAND NEMARAM  PRAJAPAT', 'count': 1},
#  {'_id': 'DEEPARAM NARAYAN RAM', 'count': 1},
#  {'_id': 'JAFAR  MAAN ALI ALI', 'count': 2},
#  {'_id': 'AVIKASH  DHRUV SHRIVAS', 'count': 1},
#  {'_id': 'HARIOM BASUDEV NAMDEV', 'count': 2},
#  {'_id': 'MATADEEN RAMGOPAL SHARMA', 'count': 1},
#  {'_id': 'BABUL KUMAR AMRESH PASWAN', 'count': 4},
#  {'_id': 'OM PRAKASH  GANESHRAM SUTHAR', 'count': 1},
#  {'_id': 'VISHAL KUMAR SURAJ THAKUR', 'count': 3},
#  {'_id': 'PUNAM RAMKARAN JANGU', 'count': 9},
#  {'_id': 'POORAN RAMESH CHANDR', 'count': 1},
#  {'_id': 'VIKASH SURAJ DEV SINGH', 'count': 1},
#  {'_id': 'RAKESH MAKHAN JATAV', 'count': 8},
#  {'_id': 'MUNNA RADHE YADAV', 'count': 9},
#  {'_id': 'KAUSHAL KUMAR SHREENIVAS YADAV', 'count': 7},
#  {'_id': 'BHAWAR  PUNAM DAS', 'count': 1},
#  {'_id': 'SONE RAM BHARAT LAL RAWAT', 'count': 2},
#  {'_id': 'HANUMAN RAM CHANDA RAM', 'count': 5},
#  {'_id': 'NAND LAL HARI  SINGH', 'count': 3},
#  {'_id': 'INDRADEV JAGO RANA', 'count': 2},
#  {'_id': 'NEMICHAND DESHPAL BISHNOI', 'count': 5},
#  {'_id': 'HADMAN RAM RAMESHWAR LAL JAT ', 'count': 1},
#  {'_id': 'JAYPAL  DEVILAL JATAV', 'count': 6},
#  {'_id': 'SARWAN LAL VANSHEERAM SOLANKI', 'count': 4},
#  {'_id': 'BHAYA  RAMPRATAP RAM', 'count': 4},
#  {'_id': 'DIPAK MAHENDRA  SINGH', 'count': 1},
#  {'_id': 'MURALI  RAMAVRIKSH -', 'count': 2},
#  {'_id': 'IDANARAM IMRATARAM', 'count': 1},
#  {'_id': 'SUDARSHAN ALAGU -', 'count': 6},
#  {'_id': 'RAM NIWAS NEHRA RAM GODARA', 'count': 4},
#  {'_id': 'SUNIL  SHITAL NISHAD', 'count': 4},
#  {'_id': 'JAVED RAMJAN ALI', 'count': 3},
#  {'_id': 'MOHAMMAD RAMJAN MOHAMMAD HAJI MOHAMMAD', 'count': 4},
#  {'_id': 'BAASUDEV GOPI KUSHWAHA', 'count': 4},
#  {'_id': 'ABRAR GULAM RUBBankI AHMAD', 'count': 2},
#  {'_id': 'KHEMCHAND  PARMESHWAR LAL SUTHAR', 'count': 2},
#  {'_id': 'PREM KUMAR  SHIVLAL SUTHAR', 'count': 19},
#  {'_id': 'NEERAJ HARIKUSUN', 'count': 2},
#  {'_id': 'BHAGIRATH PITHARAM  ', 'count': 2},
#  {'_id': 'RAMCHANDRA VISHANU DEV SAH', 'count': 4},
#  {'_id': 'VISHNU  GORAKH SINGH SINGH', 'count': 1},
#  {'_id': 'GANPAT RAM LAXMAN RAM RAM', 'count': 1},
#  {'_id': 'CHANDAN KUMAR VIJAY REENA ', 'count': 3},
#  {'_id': 'SANJAY RAMAJI RAMAJI', 'count': 4},
#  {'_id': 'AMAR SINGH HALUKA  KUSHWAHA', 'count': 2},
#  {'_id': 'SANJAY RAMJI GOUR', 'count': 9},
#  {'_id': 'RAJESH RAMCHANDER YADAV', 'count': 1},
#  {'_id': 'RAVI GHANSHYAM', 'count': 1},
#  {'_id': 'AMIT   JAGDISH BHARGAV', 'count': 3},
#  {'_id': 'MUNI RAM RAMESHWAR LAL SUTHAR', 'count': 1},
#  {'_id': 'MURLIDHAR NIRANMAL SUTHAR SUTHAR', 'count': 1},
#  {'_id': 'LAXMAN  JADUNANDAN SAH', 'count': 1},
#  {'_id': 'RAVINDAR BALVIR SINGH', 'count': 2},
#  {'_id': 'SHIV LAL ARJUN RAM', 'count': 7},
#  {'_id': 'JAYCHANDRA GYANARAM GODARA', 'count': 4},
#  {'_id': 'HADMAN RAM IMILAL ', 'count': 1},
#  {'_id': 'SINTU KUMAR SHIVJI', 'count': 1},
#  {'_id': 'TUN TUN  JAGDISH SHAH', 'count': 2},
#  {'_id': 'NORANG RAM IMILAL ', 'count': 1},
#  {'_id': 'SUNEEL  ASHAV RAWAT', 'count': 4},
#  {'_id': 'RAKESH  PARMESHWAR LAL SUTHAR', 'count': 2},
#  {'_id': 'BHADERRAM  JAGDISH NAI', 'count': 1},
#  {'_id': 'RUPSINGH SOBRAN KUSHWAHA', 'count': 4},
#  {'_id': 'BHAWANI SINGH GOPAL SINGH SINGH', 'count': 1},
#  {'_id': 'SURAJ PARUSHOTAM  PANCHARIYA', 'count': 5},
#  {'_id': 'DILIP SUTHAR BHANWARLAL SUTHAR', 'count': 1},
#  {'_id': 'MAHENDRA   MURALI', 'count': 5},
#  {'_id': 'RAMNIVAS PHUNDEE', 'count': 1},
#  {'_id': 'HARI RAM BHAKTI RAM ', 'count': 4},
#  {'_id': 'ADNAN HUSAIN AFTAB HUSAIN  HUSAIN', 'count': 12},
#  {'_id': 'VIKRAM GUMAN SINGH', 'count': 2},
#  {'_id': 'BANWARI LAL SURAJ MAL JANGID', 'count': 2},
#  {'_id': 'RAKESH LAL BAHADUR THAKUR', 'count': 2},
#  {'_id': 'PAWAN RAMAKANT YADAV', 'count': 5},
#  {'_id': 'MITHILESH KAPIL DEV SHARMA', 'count': 1},
#  {'_id': 'SUKDEV SUNGA RAM', 'count': 1},
#  {'_id': 'SHIVRAM PRABHURAM CHAUDHARI', 'count': 2},
#  {'_id': 'RAMESH BALIKARAN -', 'count': 5},
#  {'_id': 'SATISH RAMSAHARE -', 'count': 4},
#  {'_id': 'PUNAM CHAND LUNA RAM -', 'count': 5},
#  {'_id': 'SURENDRA BHEEMSEN', 'count': 2},
#  {'_id': 'MUNI RAM RAMESWAR LAL -', 'count': 6},
#  {'_id': 'ANIL REVANTRAM  SUTHAR', 'count': 1},
#  {'_id': 'VIJAY    SAKAL DEV CHAUHAN', 'count': 4},
#  {'_id': 'SANDEEP POORAN DARJI KAROLIYA', 'count': 2},
#  {'_id': 'RAM KUMAR  ASHURAM SUTHAR SUTHAR', 'count': 1},
#  {'_id': 'PRABHURAM NARSIRAM -', 'count': 1},
#  {'_id': 'SHATRUDHAN GOGAI VISHWAKARMA', 'count': 4},
#  {'_id': 'AMANA RAM BHANWAR LAL ', 'count': 4},
#  {'_id': 'HARI RAM ANNA RAM SUTHAR', 'count': 4},
#  {'_id': 'RAJESH JAGDISH RANA RANA', 'count': 7},
#  {'_id': 'MOHAN LAL GITARAM SUTHAR', 'count': 7},
#  {'_id': 'SANJAY KUMAR  KHIMJIBHAII BABARIYA', 'count': 6},
#  {'_id': 'RAVINDAR MANIKLAL SAH', 'count': 2},
#  {'_id': 'VINOD SINGH  CHANDRAPAL  JATAV', 'count': 1},
#  {'_id': 'RAKESH NEMARAM SUTHAR', 'count': 4},
#  {'_id': 'FARMAN MANJUR ALI', 'count': 1},
#  {'_id': 'UMESH BHULLAN -', 'count': 9},
#  {'_id': 'GAJENDRA DURGARAM', 'count': 3},
#  {'_id': 'GOVIND RAM RAMESHWAR LAL', 'count': 4},
#  {'_id': 'RAJURAM SURJA RAM SUTHAR', 'count': 1},
#  {'_id': 'NATBAR  KISHAN DEV SAH', 'count': 3},
#  {'_id': 'RAM SURAJ NANDLAL GAUD', 'count': 1},
#  {'_id': 'MANSUR NANJIBHAI NAVAR', 'count': 3},
#  {'_id': 'SHARVAN   SATYNARAYAN SAH', 'count': 2},
#  {'_id': 'GUDDU KUMAR RAMAI', 'count': 1},
#  {'_id': 'RAKESH  BABULAL SUTHAR', 'count': 1},
#  {'_id': 'RAM KISHUN DURYODHAN', 'count': 8},
#  {'_id': 'RAUSHAN KUMAR SANJAY  SAH', 'count': 4},
#  {'_id': 'VIKRAM RAMCHANDRA SUTHAR', 'count': 3},
#  {'_id': ' RAMAVATAR PRAJAPT BHAGWANA RAM   ', 'count': 1},
#  {'_id': 'VEER SINGH MISHRI KUSHWAH', 'count': 3},
#  {'_id': 'CHHOTU RAM  LALURAM ALI', 'count': 1},
#  {'_id': 'SIKANDAR MOHAMMED ISHAQ', 'count': 3},
#  {'_id': 'SUNIL  KALU GIRI GIRI', 'count': 2},
#  {'_id': 'MAHENDRA KUMAR MUNI RAM', 'count': 6},
#  {'_id': 'FULBADAN SURESH ', 'count': 6},
#  {'_id': 'SACHIN NARESHKUMAR KUMAR ', 'count': 1},
#  {'_id': 'PUROSHOTTUM  JHOULI SHARMA SHARMA', 'count': 1},
#  {'_id': 'GYAN SINGH RAMPRAKASH RAWAT', 'count': 1},
#  {'_id': 'KANHAIYALAL SHANKAR DAS', 'count': 5},
#  {'_id': 'KUSHAL  BHANWAR SINGH SINGH', 'count': 1},
#  {'_id': 'SURENDRA NAVAL SINGH', 'count': 1},
#  {'_id': 'AMARJEET MAHENDRA PASWAN', 'count': 1},
#  {'_id': 'OMPRAKASH DULA RAM -', 'count': 5},
#  {'_id': 'HARI RAM JETHA RAM', 'count': 1},
#  {'_id': 'SHYAM BAHADUR SAH', 'count': 4},
#  {'_id': 'ABHISHEK DIGVIJAY SINGH SINGH', 'count': 3},
#  {'_id': 'ROHIT KUMAR SURENDRA KUSHWAHA', 'count': 5},
#  {'_id': 'ISHWAR KHEMCHAND', 'count': 2},
#  {'_id': 'CHHOTULAL KANARAM -', 'count': 16},
#  {'_id': 'MAHUBUB NATHUKHAN', 'count': 1},
#  {'_id': 'DHARMRAJ CHANDRABALI ', 'count': 7},
#  {'_id': 'SUBHASH NEMA RAM SUTHAR', 'count': 1},
#  {'_id': 'AMIT KUMAR PANCHAN SHARMA', 'count': 2},
#  {'_id': 'KAILASH  BHAGIRATH NAI', 'count': 1},
#  {'_id': 'RAJARAM RAMKUMAR  ', 'count': 4},
#  {'_id': 'SHAILESH KUMAR SHURENDRA KUSHWAH', 'count': 2},
#  {'_id': 'MANOJ  KUMAR LABHU RAM', 'count': 1},
#  {'_id': 'SHAHRUKH AAMIN MOHAMMAD', 'count': 1},
#  {'_id': 'MANARAM RAWRARAM SUTHAR SUTHAR', 'count': 1},
#  {'_id': 'UDAYRAM GYASIRAM  JATAV', 'count': 1},
#  {'_id': 'NITESH KUMAR KUSHESHWAR SAH', 'count': 4},
#  {'_id': 'BIRENDER KUMAR MAHANTHI SAH SAH', 'count': 3},
#  {'_id': 'MURLIDHAR CHHIMPA SUGNA RAM', 'count': 1},
#  {'_id': 'PUNAMCHAND KALURAM', 'count': 3},
#  {'_id': 'SHRAWAN RAM BHAGWANA RAM MANJHU', 'count': 2},
#  {'_id': 'MADA RAM PANNA RAM JAT', 'count': 3},
#  {'_id': 'AMAN KUMAR NAVAL KISHOR  GUPTA', 'count': 2},
#  {'_id': 'ASHOK BAJRANG LAL', 'count': 2},
#  {'_id': 'JAGDISH  SHANKAR LAL', 'count': 3},
#  {'_id': 'SURAJ KUMAR SHIV BALAK PRASAD', 'count': 1},
#  {'_id': 'BALVIR BHEEMA JATAV', 'count': 1},
#  {'_id': 'SHIV LAL SHERA RAM MAHIYA', 'count': 1},
#  {'_id': 'LIKHMA RAM DANA RAM ', 'count': 4},
#  {'_id': 'DILIP SATYNARAYAN ', 'count': 2},
#  {'_id': 'RAJURAM MALA RAM PRAJAPAT', 'count': 1},
#  {'_id': 'BHAGIRATH RAVATRAM PRAJAPAT', 'count': 1},
#  {'_id': 'PAVAN  VIRENDRA TIWARI', 'count': 4},
#  {'_id': 'RAMESH KAHNIYA LAL SUTHAR SUTHAR', 'count': 1},
#  {'_id': 'SHRAVAN SINGH MAL SINGH SINGH', 'count': 1},
#  {'_id': 'MAHADEV REVANT  DAS', 'count': 1},
#  {'_id': 'RANDIR KAILASH KUMAR', 'count': 4},
#  {'_id': 'LEKH RAM RAMDHAN ', 'count': 2},
#  {'_id': 'ASHOK RAMNAGINA NISHAD', 'count': 2},
#  {'_id': 'SHIV SHANKAR  SURJA RAM SUTHAR', 'count': 2},
#  {'_id': 'RAJKUMAR PRABHUDAYAL SUTHAR', 'count': 2},
#  {'_id': 'BRAHAMDEV BALKI RANA', 'count': 6},
#  {'_id': 'MAHENDRA BHIKHA RAM SUTHAR', 'count': 1},
#  {'_id': 'KANHAIYALAL BIRAMDEV MISTRY', 'count': 5},
#  {'_id': 'WARIS ALI HAJRAT ALI ALI', 'count': 1},
#  {'_id': 'MUKAN SINGH BHOM SINGH SINGH', 'count': 1},
#  {'_id': 'SURENDRA KISHOR -', 'count': 3},
#  {'_id': 'RAHUL KUMAR SURESH SAH SAH', 'count': 5},
#  {'_id': 'HUKAM CHAND HARI RAM', 'count': 2},
#  {'_id': 'RAM DAYAL AMARARAM', 'count': 2},
#  {'_id': 'DHARMRAJ  LALCHAND  SUTHAR', 'count': 2},
#  {'_id': 'SRAVAN  LABHU RAM RAM', 'count': 1},
#  {'_id': 'SITA RAM KISHAN DAS PRAJAPAT', 'count': 1},
#  {'_id': 'BHAWANI SINGH RAM SINGH', 'count': 1},
#  {'_id': 'AKHILESH LAKSHMAN  SINGH', 'count': 2},
#  {'_id': 'DILEEP  JOKHAN  PASWAN', 'count': 2},
#  {'_id': 'MOHAR SINGH BACCHURAM JATAV', 'count': 1},
#  {'_id': 'SURESH  SHRILAL KUSHWAHA', 'count': 3},
#  {'_id': 'VINOD  NARSINGH SINGH', 'count': 4},
#  {'_id': 'ISHWAR GOVIND', 'count': 1},
#  {'_id': 'RAJU  SOHAN SINGH', 'count': 2},
#  {'_id': 'OM PRAKASH HANUMAN RAM', 'count': 2},
#  {'_id': 'MITHILESH KUMAR DHANESH  SINGH', 'count': 2},
#  {'_id': 'PANNELAL RAGHO', 'count': 8},
#  {'_id': 'LIYAKAT ALI CHAND ALI ALI', 'count': 1},
#  {'_id': 'LAVKESH  RAMDEEN  NARASOLIYA', 'count': 3},
#  {'_id': 'YUSUF MAN ALI ALI', 'count': 1},
#  {'_id': 'ANIL PARIMAL JATAV', 'count': 2},
#  {'_id': 'SANTOSH SATYANARAYAN', 'count': 1},
#  {'_id': 'BANTI  GOPI KUSHWAHA', 'count': 5},
#  {'_id': 'DEVI LAL RAMESHWAR LAL -', 'count': 3},
#  {'_id': 'ANOPA RAM DULA RAM GODAR', 'count': 2},
#  {'_id': 'SUNIL KUMAR RAJENDRA SINGH SINGH', 'count': 2},
#  {'_id': 'PANNELAL JURJODHAN', 'count': 5},
#  {'_id': 'SURENDRA PUKHRAJ BHARGAV', 'count': 2},
#  {'_id': 'RAJU   JHABAR SINGH', 'count': 2},
#  {'_id': 'MOHAR SINGH SIYARAM KUSHWAH', 'count': 6},
#  {'_id': 'LEKH RAM ASU RAM', 'count': 1},
#  {'_id': 'SHERA RAM RAMDHAN SUTHAR', 'count': 5},
#  {'_id': 'DEENDAYAL KAMAL KISHORE SHARMA', 'count': 2},
#  {'_id': 'SANJAY  RAMCHANDRA', 'count': 1},
#  {'_id': 'RAJ RESHAM MEENA', 'count': 1},
#  {'_id': 'RAJU RAM RAM CHANDRA SUTHAR', 'count': 1},
#  {'_id': 'DIPAK HARIBHAI CHAUHAN', 'count': 9},
#  {'_id': 'NATHMAL MADAN DAS DAS', 'count': 2},
#  {'_id': 'DHARMENDRA RAMANIWAS', 'count': 3},
#  {'_id': 'KURBAN  RAMJAN ALI', 'count': 2},
#  {'_id': 'AHARI SINGH PRAHLAD KUSHWAH KUSHWAH', 'count': 1},
#  {'_id': 'KHETHA RAM SURJA RAM -', 'count': 3},
#  {'_id': 'AMIT RAMAKANT YADAV', 'count': 6},
#  {'_id': 'INDRJIT TRIBHOOWAN', 'count': 2},
#  {'_id': 'ABHISHEK OMPRAKASH', 'count': 3}]

# %%
month, year = 4,2021
start_date = str(year)+"-"+str(month)+"-01"
end_date = str(year)+"-"+str(month)+"-" + str(calendar.monthrange(year, month)[1])
today = date.today()
start_date = datetime.strptime(start_date, '%Y-%m-%d')
end_date = datetime.strptime(end_date, '%Y-%m-%d')

total_footfall_query = [{'$match': {'date': {"$gte": start_date, "$lte": end_date}}},
                            {"$group": {'_id': '$site_name',
                                        'total_worker_footfall': {'$sum': 1},
                                        }
                             }
                            ]

total_footfall_project_wise_data = attendances.aggregate(total_footfall_query)
data = list(total_footfall_project_wise_data)
data
# Out:
# [{'_id': 'INDIABULLS BLU-PENT HOUSE', 'total_worker_footfall': 445},
#  {'_id': 'JWC RETAIL', 'total_worker_footfall': 483},
#  {'_id': 'SWATI INTERIORS', 'total_worker_footfall': 191},
#  {'_id': 'MAKER CHAMBER', 'total_worker_footfall': 3},
#  {'_id': 'GODREJ TWO', 'total_worker_footfall': 1},
#  {'_id': 'KARUNA SINDHU', 'total_worker_footfall': 424},
#  {'_id': 'INDIABULLS 20TH FLOOR', 'total_worker_footfall': 556},
#  {'_id': 'DLF LIMITED', 'total_worker_footfall': 3372},
#  {'_id': 'HYDE PARK', 'total_worker_footfall': 507},
#  {'_id': 'SWATI INTERIOR CONCEPTS PVT. LTD.', 'total_worker_footfall': 1448},
#  {'_id': 'INDIABULLS 44 & 45 floor', 'total_worker_footfall': 92}]

# %%
def convert_to_HTML_table(data,column_names):

    headers,table_body = "",""

    for i in range(len(column_names)):
        column_header = "<th>{}</th>".format(column_names[i])
        headers = headers + column_header
        headers_element = "<tr>"+str(headers)+"</tr>"


    for d in data:
        parent_row = ""

        for i in d.keys():
            parent_row = parent_row + "<td>"+str(d[i])+"</td>"
        table_body = table_body + "<tr>"+ parent_row + "</tr>"

    table_HTML = "<table>"+headers_element + table_body+"</table>"

    return table_HTML

    
    
convert_to_HTML_table(data,column_names=["SITE","FOOTFALL"])
# Out:
# '<table><tr><th>SITE</th><th>FOOTFALL</th></tr><tr><td>INDIABULLS BLU-PENT HOUSE</td><td>445</td></tr><tr><td>JWC RETAIL</td><td>483</td></tr><tr><td>SWATI INTERIORS</td><td>191</td></tr><tr><td>MAKER CHAMBER</td><td>3</td></tr><tr><td>GODREJ TWO</td><td>1</td></tr><tr><td>KARUNA SINDHU</td><td>424</td></tr><tr><td>INDIABULLS 20TH FLOOR</td><td>556</td></tr><tr><td>DLF LIMITED</td><td>3372</td></tr><tr><td>HYDE PARK</td><td>507</td></tr><tr><td>SWATI INTERIOR CONCEPTS PVT. LTD.</td><td>1448</td></tr><tr><td>INDIABULLS 44 & 45 floor</td><td>92</td></tr></table>'

# %%
table_body = "" 

for d in data:
    parent_row = ""

    for i in d.keys():
        parent_row = parent_row + "<td>"+str(d[i])+"</td>"
    table_body = table_body + "<tr>"+ parent_row + "</tr>"

table_body
# Out:
# '<tr><td>INDIABULLS BLU-PENT HOUSE</td><td>445</td></tr><tr><td>JWC RETAIL</td><td>483</td></tr><tr><td>SWATI INTERIORS</td><td>191</td></tr><tr><td>MAKER CHAMBER</td><td>3</td></tr><tr><td>GODREJ TWO</td><td>1</td></tr><tr><td>KARUNA SINDHU</td><td>424</td></tr><tr><td>INDIABULLS 20TH FLOOR</td><td>556</td></tr><tr><td>DLF LIMITED</td><td>3372</td></tr><tr><td>HYDE PARK</td><td>507</td></tr><tr><td>SWATI INTERIOR CONCEPTS PVT. LTD.</td><td>1448</td></tr><tr><td>INDIABULLS 44 & 45 floor</td><td>92</td></tr>'

# %%
for d in data:
    print(type(d['total_worker_footfall']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
ids = tuple([d['_id'] for d in data])
footfalls = [d['total_worker_footfall'] for d in data]

# %%
import pygal


# First import pygal
bar_chart = pygal.Bar()
bar_chart.x_labels = ids
bar_chart.add('worker footfall ', footfalls)  
bar_chart.render_to_png('chart.png')
